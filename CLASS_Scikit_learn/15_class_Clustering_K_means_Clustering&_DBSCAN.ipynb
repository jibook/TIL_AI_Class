# %% [markdown]
# <a href="https://colab.research.google.com/github/jibook/git-remote/blob/master/15_class_Clustering_K_means_Clustering%26_DBSCAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # K-means Clustering

# %% [markdown]
# ### make_blobs

# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import seaborn as sns 
sns.set()
import numpy as np 

import pandas as pd

# %%
from sklearn.datasets import make_blobs

# %%
from sklearn.datasets import make_blobs

X, y_ture = make_blobs(n_samples = 300, centers = 4, cluster_std= 0.60, random_state = 0)
plt.scatter(X[:,0], X[:,1], s= 50)

# %% [markdown]
# ##### K-means 군집화 모델 인스턴스화 및 학습

# %%
from sklearn.cluster import KMeans

# %%
Kmeans = KMeans(n_clusters= 4)
Kmeans.fit(X)
# Out:
# KMeans(n_clusters=4)

# %%
y_kmeans = Kmeans.predict(X)

# %%
print(y_kmeans)
# Out:
# [0 1 2 1 0 0 3 2 1 1 3 1 2 1 0 2 2 0 3 3 0 0 2 3 3 2 0 2 3 2 1 1 2 1 1 1 1
#  1 3 0 2 3 2 2 3 3 1 3 1 0 3 0 1 0 0 3 1 3 1 0 1 2 1 3 3 3 1 0 1 3 2 3 1 3
#  3 1 3 2 0 1 0 2 0 0 1 2 0 2 1 1 2 0 1 3 3 2 0 0 2 3 1 0 1 0 2 0 0 2 1 2 3
#  3 0 1 0 2 1 0 0 2 3 0 3 0 0 0 0 3 0 3 1 3 3 0 1 3 3 1 2 1 1 3 2 3 2 3 1 2
#  1 1 1 2 1 2 0 3 1 3 0 2 1 2 2 0 2 3 3 2 0 2 2 1 0 2 3 1 0 0 2 3 0 2 3 3 2
#  2 2 2 0 1 2 3 2 2 3 3 3 2 3 1 2 3 0 3 2 1 3 1 2 1 2 3 2 2 1 3 3 0 0 2 1 0
#  0 3 0 3 2 1 1 2 2 1 2 0 3 2 0 3 1 3 0 2 0 1 1 1 1 3 3 1 2 3 0 2 3 3 3 0 0
#  1 2 2 3 0 1 3 2 1 2 0 0 3 3 2 0 0 0 2 1 1 0 0 2 0 0 0 1 3 1 2 0 0 1 1 1 0
#  0 2 1 3]

# %% [markdown]
# ##### K-means 군집화- 결과 시각화

# %%
plt.scatter(X[:,0], X[:,1], c=y_kmeans, s=50, cmap = 'viridis')
centers = Kmeans.cluster_centers_
plt.scatter(centers[:,0], centers[:,1], c= 'black', s = 200, alpha= 0.5)

# %% [markdown]
# ### K-means Clustering 선형군집 경계로 한정

# %% [markdown]
# ### 비선형경계를 가지는 자료의 경우

# %%
from sklearn.datasets import make_moons

# %%
X, y = make_moons(200, noise=0.05, random_state= 0)

# %%
labels = KMeans(2, random_state= 0).fit_predict(X)
plt.scatter(X[:,0], X[:,1], c=labels, s=50, cmap = 'viridis')

# %% [markdown]
# ### 필기체 숫자인식에 적용

# %%
from sklearn.datasets import load_digits

# %%
digits = load_digits()
digits.data.shape
# Out:
# (1797, 64)

# %% [markdown]
# ##### 학습 및 예측

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters= 10, random_state= 0)
cluster = kmeans.fit_predict(digits.data)

# %%
kmeans.cluster_centers_.shape
# Out:
# (10, 64)

# %% [markdown]
# 64차원의 군집 10개

# %% [markdown]
# ##### 클러스트 중심확인

# %%
fig, ax = plt.subplots(2,5, figsize=(8,3))
centers = kmeans.cluster_centers_.reshape(10,8,8)

for axi, center in zip(ax.flat, centers):
  axi.set(xticks=[], yticks=[])
  axi.imshow(center, interpolation='nearest', cmap= plt.cm.binary)

# %% [markdown]
# # DBSCAN(Density Based Spatial Clustering of Application with Nosie

# %%
from sklearn.datasets import make_moons
X, y = make_moons(200, noise=0.05, random_state= 0)

# %%
from sklearn.cluster import DBSCAN

D_labels = DBSCAN(eps=0.3, min_samples=15).fit_predict(X)
plt.scatter(X[:,0],X[:,1],c=D_labels, s=50, cmap='viridis')

# %%
D_labels_0 = DBSCAN(eps=0.5, min_samples=15).fit_predict(X)
plt.scatter(X[:,0],X[:,1],c=D_labels_0, s=50, cmap='viridis')

# %%
D_labels_1 = DBSCAN(eps=0.3, min_samples=20).fit_predict(X)
plt.scatter(X[:,0],X[:,1],c=D_labels_1, s=50, cmap='viridis')

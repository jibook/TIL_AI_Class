# %% [markdown]
# <a href="https://colab.research.google.com/github/jibook/git-remote/blob/master/17_class_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(88)
df = pd.DataFrame({'A':np.linspace(1,10,10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10,4), columns=list('BCDE'))], axis =1)

# %%
df.iloc[3,3] = np.nan
df.iloc[0,2]  =np.nan

# %%
print(df)
# Out:
#       A         B         C         D         E
# 0   1.0  0.106884       NaN  0.956563  0.068411
# 1   2.0  1.068514  0.997183 -0.931548  0.730430
# 2   3.0 -0.171214 -1.288691  1.061436 -0.040501
# 3   4.0 -0.903721 -1.554133       NaN  0.200526
# 4   5.0 -0.747329  1.068081 -0.277024  0.086557
# 5   6.0 -0.253221 -1.212041  0.277273  0.552219
# 6   7.0 -0.467743 -1.427493  0.885805  2.360634
# 7   8.0 -1.522006 -0.215945  0.190327  0.722256
# 8   9.0 -0.870716  0.101749  0.555358  0.962261
# 9  10.0  1.433499 -0.701818 -0.856952 -0.858158

# %%
df.style.highlight_max()
# Out:
# <style type="text/css">
# #T_bf819_row2_col3, #T_bf819_row4_col2, #T_bf819_row6_col4, #T_bf819_row9_col0, #T_bf819_row9_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_bf819_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf819_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bf819_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_bf819_row0_col1" class="data row0 col1" >0.106884</td>
#       <td id="T_bf819_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_bf819_row0_col3" class="data row0 col3" >0.956563</td>
# ...

# %%
df.style.highlight_max(axis=1)
# Out:
# <style type="text/css">
# #T_80a3f_row0_col0, #T_80a3f_row1_col0, #T_80a3f_row2_col0, #T_80a3f_row3_col0, #T_80a3f_row4_col0, #T_80a3f_row5_col0, #T_80a3f_row6_col0, #T_80a3f_row7_col0, #T_80a3f_row8_col0, #T_80a3f_row9_col0 {
#   background-color: yellow;
# }
# </style>
# <table id="T_80a3f_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80a3f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_80a3f_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_80a3f_row0_col1" class="data row0 col1" >0.106884</td>
#       <td id="T_80a3f_row0_col2" class="data row0 col2" >nan</td>
# ...

# %%
df.style.highlight_min()
# Out:
# <style type="text/css">
# #T_26f8a_row0_col0, #T_26f8a_row1_col3, #T_26f8a_row3_col2, #T_26f8a_row7_col1, #T_26f8a_row9_col4 {
#   background-color: yellow;
# }
# </style>
# <table id="T_26f8a_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26f8a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_26f8a_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_26f8a_row0_col1" class="data row0 col1" >0.106884</td>
#       <td id="T_26f8a_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_26f8a_row0_col3" class="data row0 col3" >0.956563</td>
# ...

# %%
df.style.highlight_null()
# Out:
# <style type="text/css">
# #T_de84a_row0_col2, #T_de84a_row3_col3 {
#   background-color: red;
# }
# </style>
# <table id="T_de84a_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de84a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_de84a_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_de84a_row0_col1" class="data row0 col1" >0.106884</td>
#       <td id="T_de84a_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_de84a_row0_col3" class="data row0 col3" >0.956563</td>
#       <td id="T_de84a_row0_col4" class="data row0 col4" >0.068411</td>
#     </tr>
#     <tr>
# ...

# %%
df.style.highlight_null(null_color='green')
# Out:
# <style type="text/css">
# #T_5519d_row0_col2, #T_5519d_row3_col3 {
#   background-color: green;
# }
# </style>
# <table id="T_5519d_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5519d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5519d_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_5519d_row0_col1" class="data row0 col1" >0.106884</td>
#       <td id="T_5519d_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_5519d_row0_col3" class="data row0 col3" >0.956563</td>
#       <td id="T_5519d_row0_col4" class="data row0 col4" >0.068411</td>
#     </tr>
#     <tr>
# ...

# %%
df.style.set_na_rep('OutoScope').highlight_null(null_color='orange')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: this method is deprecated in favour of `Styler.format(na_rep=..)`
#   """Entry point for launching an IPython kernel.
# <style type="text/css">
# #T_40534_row0_col2, #T_40534_row3_col3 {
#   background-color: orange;
# }
# </style>
# <table id="T_40534_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40534_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_40534_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_40534_row0_col1" class="data row0 col1" >0.106884</td>
# ...

# %%
df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_b32ab_row0_col0, #T_b32ab_row1_col3, #T_b32ab_row3_col2, #T_b32ab_row7_col1, #T_b32ab_row9_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_b32ab_row0_col1 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_b32ab_row0_col2, #T_b32ab_row3_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_b32ab_row0_col3 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_b32ab_row0_col4 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_b32ab_row1_col0 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_b32ab_row1_col1 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_b32ab_row1_col2 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_b32ab_row1_col4 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_b32ab_row2_col0, #T_b32ab_row8_col1 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_b32ab_row2_col1 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# ...

# %%
df.style.set_properties(**{'border':'1.3px solid green', 'color':'magenta'})
# Out:
# <style type="text/css">
# ...

# %%
df.style.bar()
# Out:
# <style type="text/css">
# #T_3fe91_row0_col0, #T_3fe91_row1_col3, #T_3fe91_row3_col2, #T_3fe91_row7_col1, #T_3fe91_row9_col4 {
#   width: 10em;
#   height: 80%;
# }
# #T_3fe91_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 55.1%, transparent 55.1%);
# }
# #T_3fe91_row0_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 94.7%, transparent 94.7%);
# }
# #T_3fe91_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 28.8%, transparent 28.8%);
# }
# #T_3fe91_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 11.1%, transparent 11.1%);
# }
# #T_3fe91_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 87.7%, transparent 87.7%);
# }
# #T_3fe91_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 97.3%, transparent 97.3%);
# }
# #T_3fe91_row1_col4 {
# ...

# %%
df.style.bar(color='green ')
# Out:
# <style type="text/css">
# #T_7eed6_row0_col0, #T_7eed6_row1_col3, #T_7eed6_row3_col2, #T_7eed6_row7_col1, #T_7eed6_row9_col4 {
#   width: 10em;
#   height: 80%;
# }
# #T_7eed6_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,green  55.1%, transparent 55.1%);
# }
# #T_7eed6_row0_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,green  94.7%, transparent 94.7%);
# }
# #T_7eed6_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,green  28.8%, transparent 28.8%);
# }
# #T_7eed6_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,green  11.1%, transparent 11.1%);
# }
# #T_7eed6_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,green  87.7%, transparent 87.7%);
# }
# #T_7eed6_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,green  97.3%, transparent 97.3%);
# }
# #T_7eed6_row1_col4 {
# ...

# %%
df.style.set_precision(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   """Entry point for launching an IPython kernel.
# <style type="text/css">
# </style>
# <table id="T_1b128_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b128_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1b128_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_1b128_row0_col1" class="data row0 col1" >0.11</td>
#       <td id="T_1b128_row0_col2" class="data row0 col2" >nan</td>
# ...

# %%
df.style.set_caption("This is DataFrame styling demo").set_precision(2).background_gradient()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   """Entry point for launching an IPython kernel.
# <style type="text/css">
# #T_140c7_row0_col0, #T_140c7_row1_col3, #T_140c7_row3_col2, #T_140c7_row7_col1, #T_140c7_row9_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_140c7_row0_col1 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_140c7_row0_col2, #T_140c7_row3_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_140c7_row0_col3 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_140c7_row0_col4 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_140c7_row1_col0 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_140c7_row1_col1 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_140c7_row1_col2 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_140c7_row1_col4 {
# ...

# %%
df.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_e2c26_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e2c26_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e2c26_row0_col1" class="data row0 col1" >0.106884</td>
#       <td id="T_e2c26_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_e2c26_row0_col3" class="data row0 col3" >0.956563</td>
#       <td id="T_e2c26_row0_col4" class="data row0 col4" >0.068411</td>
#     </tr>
#     <tr>
#       <td id="T_e2c26_row1_col0" class="data row1 col0" >2.000000</td>
#       <td id="T_e2c26_row1_col1" class="data row1 col1" >1.068514</td>
# ...

# %%
df.style.hide_columns('B')
# Out:
# <style type="text/css">
# </style>
# <table id="T_580d6_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_580d6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_580d6_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_580d6_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_580d6_row0_col3" class="data row0 col3" >0.956563</td>
#       <td id="T_580d6_row0_col4" class="data row0 col4" >0.068411</td>
#     </tr>
#     <tr>
#       <th id="T_580d6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_580d6_row1_col0" class="data row1 col0" >2.000000</td>
# ...

# %%
df.style.format("{:.3%}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_9aab9_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9aab9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9aab9_row0_col0" class="data row0 col0" >100.000%</td>
#       <td id="T_9aab9_row0_col1" class="data row0 col1" >10.688%</td>
#       <td id="T_9aab9_row0_col2" class="data row0 col2" >nan%</td>
#       <td id="T_9aab9_row0_col3" class="data row0 col3" >95.656%</td>
#       <td id="T_9aab9_row0_col4" class="data row0 col4" >6.841%</td>
#     </tr>
#     <tr>
#       <th id="T_9aab9_level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
df.style.format("{:.3%}", na_rep = "&&")
# Out:
# <style type="text/css">
# </style>
# <table id="T_99e64_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99e64_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_99e64_row0_col0" class="data row0 col0" >100.000%</td>
#       <td id="T_99e64_row0_col1" class="data row0 col1" >10.688%</td>
#       <td id="T_99e64_row0_col2" class="data row0 col2" >&&</td>
#       <td id="T_99e64_row0_col3" class="data row0 col3" >95.656%</td>
#       <td id="T_99e64_row0_col4" class="data row0 col4" >6.841%</td>
#     </tr>
#     <tr>
#       <th id="T_99e64_level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
# p30부터
